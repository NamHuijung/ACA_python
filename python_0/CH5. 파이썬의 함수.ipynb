# %% [markdown]
# # section09. 내장 함수

# %% [markdown]
# **문자열 내장 함수**
# 1. chr() : 특정 문자의 유니코드 값을 전달하면 해당 유니코드 값을 가진 문자를 반환하는 함수
# 2. eval() : 실행하고자 하는 표현식을 문자열로 전달하면 표현식의 결괏값을 반환하는 함수
# 3. format() : 전달받은 인수와 포맷 코드에 따라 형식을 갖춘 문자열을 반환하는 함수
# - format(10000, '_') : 천 단위 구분 기호로 밑줄(__)을 사용
# - format(10000, ',') : 천 단위 구분 기호로 쉽표(,)를 사용
# 4. str() : 전달받은 인수를 문자열로 반환하여 반환하는 함수

# %%
# 02.문자열 내장 함수
'''
파일명 : Ex09-1.py
개요 : 간단한 계산기 프로그램
      사용자로부터 계산식을 입력받아 결과를 출력
작성자 : 남희정
최초작성일 : 2021-09-01
'''

expr = input('계산식을 입력하세요 >> ')
result = eval(expr)
print(expr + '=' + str(result))
# Out:
# 계산식을 입력하세요 >> 3+8
# 3+8=11

# %% [markdown]
# **숫자 내장 함수**
# 1. abs() : 전달된 인수(정수 또는 실수)의 절댓값을 반환
# 2. divmod() : 전달된 두 인수를 나누어 몫과 나머지를 한 쌍의 결과(튜플)로 반환
# 3. float() : 전달된 인수(숫자 또는 문자열)를 실수로 만들어 반환
# 4. int() : 전달된 인수(숫자 또는 문자열)를 정수로 만들어 반환
# 5. max() : 전달된 인수 중 가장 큰 값을 반환
# 6. min() : 전달된 인수 중 가장 작은 값을 반환
# 7. pow() : 전달된 두 인수의 거듭제곱을 반환, 연산자 '**'와 같음
# 8. rount() : 전달된 인수를 이용해 반올림한 값을 반환
# 전달된 인수가 하나이면 정수로 반올림한 값을 반환,
# 전달된 인수가 2개이면 두 번째로 전달한 인수만큼 소수점을 남김
# 9. sum() : 전달된 리스트나 튜플과 같은 반복 가능 객체의 합계를 반환, 숫자가 아니라면 오류

# %%
# 03. 숫자 내장 함수
'''
파일명 : Ex09-2.py
개요 : 빵집에서 10000원을 주고 빵과 거스름돈을 받는 상황을 구현
      빵 1개의 가격은 3000원
작성자 : 남희정
최초작성일 : 2021-09-01
'''

money = 10000
price = 3000
result = divmod(money, price)
print('빵을 {}개 사고 {}원이 남았습니다.'.format(result[0], result[1]))
# Out:
# 빵을 3개 사고 1000원이 남았습니다.

# %% [markdown]
# **시퀸스 내장 함수**
# 1. enumerate([리스트]) : 리스트에 저장된 요소와 해당 요소의 인덱스가 튜플 형태로 함께 추출
# 2. range() : 전달된 인수값에 따라 시퀸스 자료형의 데이터를 생성하는 함수
# - range(stop) : 0부터 stop 사이의 모든 정수가 생성
# - range(start, stop) : start부터 stop 사이의 모든 정수가 생성
# - range(start, stop, step) : start부터 stop 사이의 정수 중에서 step만큼의 차이를 가지고 있는 정수가 생성
# 3. len() : 전달된 객체의 길이(항목 수)를 반환하는 함수
# 4. sorted() : 전달된 반복 가능 객체의 오름차순 정렬 결과를 반환
#  reverse = True 옵션을 추가할 경우 내림차순 정렬 결과를 반환
#  실제로 정렬X, 다른 리스트에 덮어쓰기
# 5. zip() : 전달된 여러 개의 반복 가능 객체의 각 요소를 튜플로 묶어서 반환하는 함수
# 전달된 반복 가능 객체들의 길이가 서로 다르면 길이가 짧은 반복 가능 객체를 기준으로 동작

# %%
# 04. 시퀀스 내장 함수
'''
파일명 : Ex09-3.py
개요 : 리스트에 월별 일수를 저장해 두고 1월부터 12월까지 월별 일수를 출력하는 프로그램
      윤년은 고려하지 않고 모두 평년이라고 가정
작성자 : 남희정
최초작성일 : 2021-09-01
'''

months = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
for month, day in enumerate(months) :
  print('{}월 = {}일'.format(month+1, day))
# Out:
# 1월 = 31일
# 2월 = 28일
# 3월 = 31일
# 4월 = 30일
# 5월 = 31일
# 6월 = 30일
# 7월 = 31일
# 8월 = 31일
# 9월 = 30일
# 10월 = 31일
# 11월 = 30일
# 12월 = 31일

# %% [markdown]
# **응용 예제**

# %%
# 1. 무지개의 일곱 색깔을 저장하는 rainbow 리스트를 생성하고 출력

rainbow = ['red', 'orange', 'yellow', 'green', 'blue', 'navy', 'purple']

for i, color in enumerate(rainbow) :
  print('무지개의 {}번째 색은 {}입니다.'.format(i+1, color))
# Out:
# 무지개의 1번째 색은 red입니다.
# 무지개의 2번째 색은 orange입니다.
# 무지개의 3번째 색은 yellow입니다.
# 무지개의 4번째 색은 green입니다.
# 무지개의 5번째 색은 blue입니다.
# 무지개의 6번째 색은 navy입니다.
# 무지개의 7번째 색은 purple입니다.

# %%
# 2. 어떤 학생의 점수를 입력받아 평균 점수, 최고 점수, 최저 점수를 구하는 성적 계산 프로그램
# 몇 개의 점수를 입력받아야 하는지 모르는 상황
# 0보다 작은 점수를 입력하면 더 이상 입력할 점수가 없음을 의미
# 입력받은 모든 점수는 exam 리스트에 저장
# 마지막에 입력된 0보다 작은 점수는 exam에 저장하지 않음

scores = []
user = 0
print('점수를 입력하세요. 더 이상 입력할 점수가 없으면 음수를 아무거나 입력하세요.')

# 점수 입력 받기
while user >= 0 :
  user = int(input('점수 입력 >> '))
  scores.append(user)

# 마지막 요소 제거
scores.pop()

print('평균 = {}, 최대 {}, 최소 = {}'.format((sum(scores)/len(scores)), max(scores), min(scores)))
# Out:
# 점수를 입력하세요. 더 이상 입력할 점수가 없으면 음수를 아무거나 입력하세요.
# 점수 입력 >> 80
# 점수 입력 >> 50
# 점수 입력 >> 60
# 점수 입력 >> 30
# 점수 입력 >> 90
# 점수 입력 >> -1
# 평균 = 62.0, 최대 90, 최소 = 30

# %% [markdown]
# # section10. 메소드

# %% [markdown]
# **메소드**
#
# 특정 객체(object)가 가지고 있는 함수
# 함수는 독립적으로 호출할 수 있지만, 메소드는 특정 객체를 통해서만 호출할 수 있다.

# %% [markdown]
# **문자열 메소드**
# 1. format() : 메소드의 인수로 변수나 값을 표시하고, 해당 값이 표시될 위치를 중괄호({})로 표시하는 방식
# 2. count() : 문자열 내부에 포함된 특정 문자열의 개수를 반환하는 메소드
# 3. find() : 문자열 내부에 포함된 특정 문자열을 찾고자 할 때 사용
# - 찾고자 하는 문자열이 있으면 그 문자열이 처음으로 나온 위치(인덱스) 반환
# - 찾는 문자열이 없는 경우 -1을 반환
# 4. rfind() : 문자열의 뒤에서 앞으로 이동하면서 찾기
# 5. index() : find()함수와 동일, 하지만 찾고자 하는 문자열이 없으면 오류
# 6. upper() : 모두 대문자로 변환한 결과를 반환
# 7. lower() : 모두 소문자로 변환한 결과를 반환
# 8. capitalize() : 첫 글자는 대문자로 변환하고 나머지는 소문자로 변환한 결과를 반환
# 9. join() : 인수로 전달한 반복가능객체(문자열, 리스트 등)의 각 요소 사이에 문자열을 포함시켜 새로운 문자열을 만들고 그 결과를 반환
# - 딕셔너리의 key를 연결해서 결과로 반환, join() 메소드에서 딕셔너리의 value는 사용되지 않는다.
# 10. split() : 하나의 문자열을 여러 개의 문자열로 분리해서 저장한 리스트를 반환
# - 기본적으로 공백 문자를 기준으로 분리하지만, 특정 문자열을 기준으로 분리
# 11. replace() : 문자열의 일부 문자열을 다른 문자열로 바꾼 결과를 반환
# - 예) s.replace('-', '') : 어떤 문자열을 제거하기 위한 용도로도 사용 가능
# 12. lsrtip() : 왼쪽 끝에 있는 불필요한 문자열을 제거한 결과를 반환
# 13. rstrip() : 오른쪽 끝에 있는 불필요한 문자열을 제거한 결과를 반환
# 14. strip() : 양쪽 끝에 있는 불필요한 문자열을 제거한 결과를 반환

# %%
# 02. 문자열 메소드
'''
파일명 : Ex10-1.py
개요 : 주민등록번호에서 생년월일 6자리를 추출하는 프로그램
      사용자로부터 하이픈을 포함한 전체 주민등록번호를 입력받아 처리
      하이픈의 위치가 올바르지 않다면 오류 메시지를 출력 다시 입력 처리
작성자 : 남희정
최초작성일 : 2021-09-06
'''

while True :
  p = input('하이픈을 포함하여 전체 주민등록번호를 입력하세요 >> ')
  if p.find('-') != 6 :
    print('하이픈의 위치가 잘목되었습니다.')
    continue
  birthday = p.split('-')[0]
  print('생년월일은 {}입니다.'.format(birthday))
  break
# Out:
# 하이픈을 포함하여 전체 주민등록번호를 입력하세요 >> 95121-1234567
# 하이픈의 위치가 잘목되었습니다.
# 하이픈을 포함하여 전체 주민등록번호를 입력하세요 >> 951211-1234567
# 생년월일은 951211입니다.

# %% [markdown]
# **리스트 메소드**
# 1. append() : 리스트의 끝에 있는 인수로 전달된 데이터를 추가
# 2. extend() : 리스트에 다른 리스트나 튜플과 같은 반복가능객체를 추가하여 기존 리스트를 확장
# 3. insert() : 리스트의 특정 인덱스에 데이터를 추가하는 메소드
# 메소드에 전달되는 첫번째 인수는 인덱스, 두번째 인수는 저장할 데이터
# 4. clear() : 리스트에 저장된 모든 요소를 삭제하는 메소드
# 5. pop() : 리스트의 마지막 요소가 반환되면서 실제로 리스트에서 제거
# 6. remove() : 인수로 전달된 값과 동일한 요소를 찾아서 제거
# 동일한 요소가 여러 개인 경우레는 그중에서 첫 번째 요소가 제거

# %%
# 03. 리스트 메소드
'''
파일명 : Ex10-2.py
개요 : 리스트에 포함된 잘못된 데이터를 모두 제거하는 프로그램
      리스트에 저장된 정상 데이터는 모두 'a'를 포함한 문자열이며, 그렇지 않은 경우 잘못된 데이터
작성자 : 남희정
최초작성일 : 2021-09-06
'''

a_list = ['above', 'cookie', 'app', 'about', 'admin', 'bisket', 'apple', 'april']
for i, item in enumerate(a_list) :
  if item.find('a') == -1 :
    print('{} 제거됩니다.'.format(a_list.pop(i)))

print(a_list)
# Out:
# cookie 제거됩니다.
# bisket 제거됩니다.
# ['above', 'app', 'about', 'admin', 'apple', 'april']

# %% [markdown]
# **세트 메소드**
# 1. 교집합
# & 연산자 또는 intersection() 메소드 함수 사용
# 2. 합집합
# \| 연산자 또는 union() 메소드 함수 사용
# 3. 차집합
# \- 연산자 또는 set.difference() 함수 사용

# %% [markdown]
# **응용 예제**

# %%
# 1. 우리나라의 전화번호는 '지역번호-국번-가입자개별번호' 형식으로 되어 있습니다.
'''
02-543-2109
02-2345-6789
032-789-0123
031-4567-8900
'''
# 어떤 형식의 전화번호를 입력하더라도 '국번'을 추출하여 출력하는 프로그램

num = input('전화번호를 입력하세요 >> ')
print(num.split('-')[1])
# Out:
# 전화번호를 입력하세요 >> 031-4567-8900
# 4567

# %%
# 2. '숫자3자리-숫자2자리-숫자5자리' 형식(예 : 123-45-67890)의 사업자등록번호를 입력받아서 형식이 맞는지 점검하는 프로그램
'''
<지시사항>
1. 전체 글자 수를 점검합니다.
2. 모든 하이픈(-)의 위치가 올바른지 점검합니다.
3. 하이픈(-)을 제외하면 모두 숫자인지 점검합니다.
'''
# isdecimal() : 숫자인 경우 True
while True :
  num = input('사업자등록번호를 입력하세요 >> ')
  condition = (len(num) == 12) and (num[3] == '-' and num[6] == '-') and ((num.replace('-', '')).isdecimal() == True)
  if condition == False :
    print('올바른 형식이 아닙니다.')
    continue
  else :
    print('올바른 형식입니다.')
    break
# Out:
# 사업자등록번호를 입력하세요 >> 123-45-6789
# 올바른 형식이 아닙니다.
# 사업자등록번호를 입력하세요 >> 12-34-56789
# 올바른 형식이 아닙니다.
# 사업자등록번호를 입력하세요 >> 123-사오-67890
# 올바른 형식이 아닙니다.
# 사업자등록번호를 입력하세요 >> 123-45-67890
# 올바른 형식입니다.

# %%
# 3. 우리 학교 성적 관리 프로그램은 다음과 같이 쉽표(,)로 구분된 문자열 형식으로 학생 이름과 성적이 입력됨
# 이 데이터를 각각 name과 score 변수에 저장하는 프로그램
user = input('')
name, score = user.split(',')
print('이름은 {}이고, 점수는 {}점입니다.'.format(name.replace('"', ''), score))
# Out:
# "김철수",85
# 이름은 김철수이고, 점수는 85점입니다.

# %% [markdown]
# # section11. 사용자 함수

# %% [markdown]
# **함수 용어 정리**
# - 함수 정의 : 사용자 함수를 새로 만드는 것을 의미
# - 인수(argument) : 사용자 함수에 전달할 입력(input)을 의미
# - 매개 변수(parameter) : 인수를 받아서 저장하는 변수를 의미
# - 반환값(return) : 사용자 함수의 출력(output)을 의미
# - 함수 호출 : 만들어진 사용자 함수를 실제로 사용하는 것을 의미

# %%
# 03. 인수와 매개변수
'''
파일명 : Ex11-1.py
개요 : 전달된 모든 인수를 모두 더해서 합계를 출력
작성자 : 남희정
최초작성일 : 2021-09-01
'''

def adder(*args) :
  print('{}의 합은 {}입니다.'.format(args, sum(args)))

adder(1,2)
adder(1,2,3)
adder(1,2,3,4)
# Out:
# (1, 2)의 합은 3입니다.
# (1, 2, 3)의 합은 6입니다.
# (1, 2, 3, 4)의 합은 10입니다.

# %%
# 04. 반환값
'''
파일명 : Ex11-2.py
개요 : 커피자판기 프로그램
      1. 커피자판기에 돈과 주문할 커피를 전달
      2. 주문할 수 있는 커피의 종류와 가격은 다음과 같다.
        아메리카노 : 1000원
        카페라떼 : 1500원
        카푸치노 : 2000원
      3. 없는 커피를 주문할 경우 입력한 돈을 그대로 반환
      4. 구매 금액이 부족하면 입력한 돈을 그대로 반환
      5. 정상 주문이면 주문한 커피와 잔돈을 반환 
작성자 : 남희정
최초작성일 : 2021-09-01
'''

def coffee_machine(money, pick) :
  print('{}원에 {}를 선택하셨습니다.'.format(money, pick))
  menu = {
      '아메리카노' : 1000,
      '카페라떼' : 1500,
      '카푸치노' : 2000
  }
  if pick not in menu :
    print('{}는 판매하지 않습니다.'.format(pick))
    return money, '없는 메뉴'
  elif menu[pick] > money :
    print('{}는 {}원입니다.'.format(pick, menu[pick]))
    return money, '금액 부족'
  else :
    return money - menu[pick], pick

order = input('커피를 선택하세요.(아메리카노, 카페라떼, 카푸치노) >> ')
pay = int(input('얼마를 내시나요? >> '))

change, coffee = coffee_machine(pay, order)
print('잔돈 {}원, 커피 {}'.format(change, coffee))
# Out:
# 커피를 선택하세요.(아메리카노, 카페라떼, 카푸치노) >> 마키아또
# 얼마를 내시나요? >> 15000
# 15000원에 마키아또를 선택하셨습니다.
# 마키아또는 판매하지 않습니다.
# 잔돈 15000원, 커피 없는 메뉴

# %% [markdown]
# **응용 예제**

# %%
# 1. 700원짜리 음료수를 뽑을 수 있는 자판기 프로그램
# 돈을 넣으면 몇 잔의 음료수를 뽑을 수 있는지 그리고 잔돈은 얼마인지 모든 경우의 수를 출력
'''
함수 정의
- 반환값 : 없음
- 함수 이름 : vending_machine()
- 매개변수 : 정수 money

코드 구성
def vending_machine(money)
    # 함수 구현

vending_machine(3000)
'''

def vending_machine(money) :
  for count in range((money // 700) + 1) :
    print('음료수 = {}개, 잔돈 = {}원'.format(count, money))
    money -= 700 

vending_machine(3000)
# Out:
# 음료수 = 0개, 잔돈 = 3000원
# 음료수 = 1개, 잔돈 = 2300원
# 음료수 = 2개, 잔돈 = 1600원
# 음료수 = 3개, 잔돈 = 900원
# 음료수 = 4개, 잔돈 = 200원

# %%
# 2. 키(key)가 '과목명', 값(value)이 '점수'인 marks 딕셔너리를 전달하면
# 해당 딕셔너리에 저장된 점수들의 평균을 반환하는 get_average() 함수 구현
'''
함수 정의
- 반환값 : 평균
- 함수 이름 : get_average()
- 매개변수 : 딕셔너리 marks

코드 구성
def get_average(marks) :
  # 함수 구현

marks = {'국어' : 90, '영어' : 80, '수학' : 85}
average = get_average(marks)
print('평균은 {}점입니다.'.format(average))
'''

def get_average(marks) :
  return sum(marks.values()) / len(marks)

marks = {'국어' : 90, '영어' : 80, '수학' : 85}
average = get_average(marks)
print('평균은 {}점입니다.'.format(average))
# Out:
# 평균은 85.0점입니다.

# %%
# 3. 결혼식에 참석하는 대부분의 사람은 축의금을 낸다.
# 축의금을 내는 사람의 이름과 그 사람이 낸 축의금을 딕셔너리에 저장하고
# 전체 축의금의 합계를 구할 수 있는 gift() 함수 구현
'''
함수 정의
- 반환값 : 없음
- 함수 이름 : gift()
- 매개변수 : 딕셔너리 dic, 사람 who, 축의금 money

코드 구성
total = 0
def gift(dic, who, money) :
  # 함수 구현

wedding = {}
gift(wedding, '영희', 5)
gift(wedding, '철수', 3)
gift(wedding, '이모', 10)
print('축의금 명단 : {}'.format(wdding))
print('전체 축의금 : {}'.format(total))
'''

total = 0
def gift(dic, who, money) :
  dic[who] = money
  global total
  total += money

wedding = {}
gift(wedding, '영희', 5)
gift(wedding, '철수', 3)
gift(wedding, '이모', 10)
print('축의금 명단 : {}'.format(wedding))
print('전체 축의금 : {}'.format(total))
# Out:
# 축의금 명단 : {'영희': 5, '철수': 3, '이모': 10}
# 전체 축의금 : 18
