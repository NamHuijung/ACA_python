# %% [markdown]
# # **1. 코랩의 성능**

# %% [markdown]
# OS 환경

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %% [markdown]
# python 버전

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# # **2. 셀 단축키**

# %% [markdown]
# 단축키 설정(컨트롤 + M,H)
